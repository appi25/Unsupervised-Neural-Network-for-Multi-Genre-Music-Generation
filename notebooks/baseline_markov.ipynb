# %% [markdown]
# # Markov Chain Baseline
#
# See `NN_Project_clean.ipynb` for the Markov chain implementation.
#
# Model: First-order token transition chain trained on REMI sequences.
# Evaluation: Human score 2.36/5 (10 participants, 5 tracks).
